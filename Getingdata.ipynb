# %%
import json
import pandas as pd
import requests
import csv

# %%
location = 'tarntaran'
location1 = 'Tarn%20Taran'
key1 = 'EB36A28R7CW4FW3M5PW4KP5Z8'
key2 = '8HNQJQGMZQKPRPGN3T6UAM9KV'
key3 = 'MLUDFLSH2DWH4PJ8HWDFPCSNB'
key4 = 'EJ36RA47MPQKB6JB39SDUEKV8'
key5 = 'RPCF6N23JJSRWDKTBS8PUXZ6W'
# key6 = 

key1 = key3
key2 = key4

for i in range(2017, 2021):
    from_date = f'{i}-01-01'
    to_date = f'{i}-12-31'

    response = 'NULL'
    if(i%2==0):
        response = requests.get(f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{location1}/{from_date}/{to_date}?unitGroup=uk&include=days&key={key1}&contentType=json')
    else:
        response = requests.get(f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{location1}/{from_date}/{to_date}?unitGroup=uk&include=days&key={key2}&contentType=json')
    
    

    if response.status_code == 200:
        # Extracting data from response
        data = response.json()["days"]

        # Save data to JSON file
        with open(f"{location}_response_{i}.json", "w") as f:
            json.dump(data, f)

# %%
# Initialize an empty list to store data from JSON files
all_data = []

# Read data from JSON files
for i in range(2017, 2021):
    filename = f"{location}_response_{i}.json"
    with open(filename, "r") as f:
        data = json.load(f)
        all_data.extend(data)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(all_data)

# Convert 'datetime' column to datetime type
df['datetime'] = pd.to_datetime(df['datetime'])

# Extract year and month from datetime
df['Year'] = df['datetime'].dt.year
df['Month'] = df['datetime'].dt.month

# Calculate average values for dew, humidity, and precip for each month and year
avg_values_df = df.groupby(['Year', 'Month'])[['temp', 'dew', 'humidity', 'precip']].mean().reset_index()

# Rename columns
avg_values_df.columns = ['Year', 'Month', 'Avg_Temp', 'Avg_Dew', 'Avg_Humidity', 'Avg_Precipitation']

# Save to CSV
avg_values_df.to_csv(f"{location}_average_weather.csv", index=False)

print(avg_values_df)
# Out:
#     Year  Month   Avg_Temp    Avg_Dew  Avg_Humidity  Avg_Precipitation
# 0   2017      1  12.267742   9.435484     85.006452           1.704806
# 1   2017      2  16.121429  10.750000     74.439286           0.164857
# 2   2017      3  19.932258  12.770968     67.835484           0.833129
# 3   2017      4  27.860000  12.016667     43.010000           1.228333
# 4   2017      5  31.793548  14.645161     38.893548           0.625194
# 5   2017      6  31.173333  21.000000     60.536667           6.572600
# 6   2017      7  30.787097  27.496774     83.880645           9.946516
# 7   2017      8  30.148387  27.267742     85.645161           3.286516
# 8   2017      9  28.720000  24.266667     79.083333           0.763567
# 9   2017     10  25.783871  19.290323     70.741935           0.000000
# 10  2017     11  17.043333  12.433333     77.920000           0.102800
# 11  2017     12  13.506452   7.774194     72.854839           0.430774
# 12  2018      1  11.948387   7.312903     77.380645           0.164355
# 13  2018      2  15.871429   9.667857     70.407143           1.027464
# 14  2018      3  21.632258  13.490323     64.458065           0.180710
# 15  2018      4  27.193333  15.536667     54.090000           0.761367
# 16  2018      5  31.819355  13.996774     37.874194           0.251290
# 17  2018      6  32.220000  20.923333     55.200000           4.161267
# 18  2018      7  30.300000  25.038710     74.893548           7.785839
# 19  2018      8  30.148387  25.254839     76.174194           2.400097
# 20  2018      9  27.760000  22.516667     74.780000           8.671433
# 21  2018     10  23.448387  17.038710     69.725806           0.552839
# 22  2018     11  18.153333  11.693333     69.086667           0.171300
# 23  2018     12  12.403226   7.348387     74.829032           0.049258
# 24  2019      1  11.158065   6.738710     77.183871           0.985419
# 25  2019      2  13.696429   9.325000     77.692857           3.513179
# 26  2019      3  18.177419  10.661290     64.954839           0.293871
# 27  2019      4  26.846667  15.373333     53.806667           1.730100
# 28  2019      5  30.367742  14.074194     41.077419           0.449774
# 29  2019      6  33.423333  17.500000     42.353333           1.007033
# 30  2019      7  30.145161  24.112903     72.351613           8.704161
# 31  2019      8  30.035484  25.093548     75.906452           4.173032
# 32  2019      9  29.173333  23.840000     74.200000           2.408033
# 33  2019     10  24.038710  18.135484     71.600000           0.769903
# 34  2019     11  18.370000  13.323333     74.370000           1.536533
# 35  2019     12  10.480645   7.806452     84.993548           1.333032
# 36  2020      1  10.551613   7.051613     81.077419           1.904774
# 37  2020      2  14.762069   9.544828     73.789655           0.602793
# 38  2020      3  18.203226  13.235484     74.932258           3.793129
# 39  2020      4  24.626667  15.820000     60.993333           1.211867
# 40  2020      5  29.919355  16.596774     48.283871           0.442516
# 41  2020      6  31.326667  20.813333     55.603333           1.384600
# 42  2020      7  30.793548  24.658065     70.958065           6.359839
# 43  2020      8  30.064516  25.658065     78.077419           8.673871
# 44  2020      9  29.906667  24.050000     72.426667           1.292233
# 45  2020     10  24.564516  15.977419     62.858065           0.000000
# 46  2020     11  16.910000  10.676667     70.283333           0.514467
# 47  2020     12  11.503226   8.177419     82.374194           1.287839

# %%
# location = "amritsar"
def csv_to_json_with_district(csv_file_path, json_file_path, district_name):
    # Read the CSV file
    with open(csv_file_path, 'r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        # Convert CSV to a list of dictionaries
        data = list(csv_reader)

    # Create a dictionary with district name and data
    json_data = {"District": district_name, "data": data}

    # Write data to a JSON file
    with open(json_file_path, 'w') as json_file:
        json.dump(json_data, json_file, indent=4)

# Example usage:
csv_file_path = f"{location}_average_weather.csv"
json_file_path = f"{location}_average_weather.json"
district_name = f"{location}"
csv_to_json_with_district(csv_file_path, json_file_path, district_name)

# %%
# def csv_to_json(csv_file_path, json_file_path):
#     # Read the CSV file
#     with open(csv_file_path, 'r') as csv_file:
#         csv_reader = csv.DictReader(csv_file)
#         # Convert CSV to a list of dictionaries
#         data = list(csv_reader)

#     # Write data to a JSON file
#     with open(json_file_path, 'w') as json_file:
#         json.dump(data, json_file, indent=4)

# # Example usage:
# csv_file_path = f"{location}_average_weather.csv"
# json_file_path = f"{location}_average_weather.json"
# csv_to_json(csv_file_path, json_file_path)
